# %%
## Import pandas dependancy and pull in the scraped file.

import pandas as pd

df1 = pd.read_csv('nevada_caucus_2_18.csv')

# %%
## Clean up work to get the sentiments aligned in a column like fashion

pos_s = df1[df1['pos_sentiment']=='yes'].reset_index()
neg_s = df1[df1['neg_sentiment']=='yes'].reset_index()
gen_s = df1[df1['general']=='yes'].reset_index()

## Creating indivual sets before appending them back together

pos_s['overall_sentiment'] = 'positive'
gen_s['overall_sentiment'] = 'general'
neg_s['overall_sentiment'] = 'negative'

# %%
## Appending datasets back together so the sentiments line up

append_df = pos_s.append(neg_s)
second_append = append_df.append(gen_s)

# %%
## Creating the new Dataframe for tokenizing the tweets

df_pos = second_append[second_append['overall_sentiment']=='positive'].reset_index()
df_neg = second_append[second_append['overall_sentiment']=='negative'].reset_index()
df_gen = second_append[second_append['overall_sentiment']=='general'].reset_index()

pos_string = df_pos['text']
neg_string = df_neg['text']
gen_string = df_gen['text']

# %%
## Tokenizing the tweets - testing

from nltk.tokenize import TweetTokenizer
tweet_tokenizer = TweetTokenizer(preserve_case=False, strip_handles=True, reduce_len=True)

def find_tweet_cand(tweets):
    for tweet in tweets:
        s= (tweet_tokenizer.tokenize(tweet))
        return s

# %%
import string
import re

## Importing stopwords 
from nltk.corpus import stopwords 
stopwords_english = stopwords.words('english')
 
## Importing porter stemmer
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()

## Importing the tokenizer 
from nltk.tokenize import TweetTokenizer

def clean_tweets(tweet):
    tweet = re.sub(r'\$\w*', '', tweet)
    
    ## Cleaing up RTs
    tweet = re.sub(r'^RT[\s]+', '', tweet)
    
    ## Removing hyperlinks
    tweet = re.sub(r'https?:\/\/.*[\r\n]*', '', tweet)
    
    ## Removing hastags
    tweet = re.sub(r'#', '', tweet)
 
    # tokenize tweets
    tokenizer = TweetTokenizer(preserve_case=False, strip_handles=True, reduce_len=True)
    tweet_tokens = tokenizer.tokenize(tweet)
 
    tweets_clean = []    
    for word in tweet_tokens:
        if (word not in stopwords_english and # remove stopwords
                word not in string.punctuation): # remove punctuation
            ##stem_word = stemmer.stem(word) # stemming word
            tweets_clean.append(word)
 
    return tweets_clean

# %%
def bag_of_words(tweet):
    words = clean_tweets(tweet)
    words_dictionary = dict([word, True] for word in words)    
    return words_dictionary
    
def get_tokens(tweet):
    words = clean_tweets(tweet)    
    return words 

# positive tweets feature set
pos_tweets_set = []
for tweet in pos_string:
    pos_tweets_set.append((bag_of_words(tweet), 'pos'))    
    
## negative tweets
neg_tweets_set = []
for tweet in neg_string:
    neg_tweets_set.append((bag_of_words(tweet), 'neg'))
    
## general tweets

gen_tweets_set = []
for tweet in gen_string:
    gen_tweets_set.append((bag_of_words(tweet), 'gen'))

# %%
from random import shuffle 
shuffle(pos_tweets_set)
shuffle(neg_tweets_set)
 
test_set = pos_tweets_set[:40] + neg_tweets_set[:40] + gen_tweets_set[:40]
train_set = pos_tweets_set[10:] + neg_tweets_set[10:] + gen_tweets_set[10:]
print(len(train_set),len(test_set))
# Out:
# 950 120

# %%
from nltk import classify
from nltk import NaiveBayesClassifier
 
classifier = NaiveBayesClassifier.train(train_set)
 
accuracy = classify.accuracy(classifier, test_set)
print(accuracy) # Output: 0.765
 
print (classifier.show_most_informative_features(60))
# Out:
# 0.7916666666666666
# Most Informative Features
#             presidential = True              gen : neg    =     28.3 : 1.0
#                   season = True              gen : pos    =     28.2 : 1.0
#                    biden = True              neg : gen    =     26.2 : 1.0
#                      eve = True              gen : neg    =     24.5 : 1.0
#                    major = True              pos : neg    =     23.5 : 1.0
#                    backs = True              pos : neg    =     23.5 : 1.0
#         berniebeatstrump = True              pos : gen    =     21.8 : 1.0
#                  notmeus = True              pos : gen    =     21.8 : 1.0
#                    video = True              neg : gen    =     17.4 : 1.0
#                    group = True              pos : neg    =     17.1 : 1.0
#              legislative = True              neg : gen    =     16.6 : 1.0
#                 nvcaucus = True              pos : gen    =     16.4 : 1.0
#                     like = True              neg : gen    =     15.7 : 1.0
#                  musters = True              neg : pos    =     15.7 : 1.0
#                   accent = True              neg : pos    =     15.7 : 1.0
#                 channels = True              neg : pos    =     15.7 : 1.0
#                     fake = True              neg : pos    =     15.7 : 1.0
#                  clinton = True              neg : gen    =     14.9 : 1.0
#                 disaster = True              neg : pos    =     12.4 : 1.0
#                      joe = True              neg : gen    =     11.9 : 1.0
#                   latino = True              pos : neg    =     11.7 : 1.0
#                     reno = True              gen : neg    =     11.3 : 1.0
#                 speaking = True              neg : gen    =     10.4 : 1.0
#           medicareforall = True              pos : gen    =     10.4 : 1.0
#               candidates = True              gen : neg    =     10.0 : 1.0
#                  hillary = True              neg : pos    =      9.9 : 1.0
#                bloomberg = True              neg : gen    =      9.4 : 1.0
#                   warren = True              pos : gen    =      9.1 : 1.0
#                  process = True              neg : gen    =      8.8 : 1.0
#                  primary = True              gen : neg    =      8.0 : 1.0
#               university = True              gen : neg    =      8.0 : 1.0
#                  rallies = True              gen : neg    =      8.0 : 1.0
#                   repeat = True              neg : gen    =      7.7 : 1.0
#                 campaign = True              neg : gen    =      7.7 : 1.0
#                     many = True              neg : gen    =      7.7 : 1.0
#                 students = True              gen : neg    =      7.4 : 1.0
#                      see = True              gen : pos    =      7.4 : 1.0
#                  sanders = True              pos : gen    =      7.0 : 1.0
#               supporters = True              pos : gen    =      7.0 : 1.0
#            southcarolina = True              pos : gen    =      7.0 : 1.0
#                    hours = True              neg : gen    =      6.5 : 1.0
#                     days = True              gen : neg    =      6.5 : 1.0
#                    rally = True              gen : neg    =      6.3 : 1.0
#                    black = True              neg : gen    =      6.3 : 1.0
#            berniesanders = True              pos : gen    =      5.8 : 1.0
#         democraticdebate = True              gen : pos    =      5.6 : 1.0
#                    would = True              neg : gen    =      5.6 : 1.0
#                 location = True              gen : neg    =      5.4 : 1.0
#               nvcaucuses = True              pos : gen    =      5.3 : 1.0
#                     said = True              neg : gen    =      5.2 : 1.0
#                     left = True              neg : gen    =      5.2 : 1.0
#                    chaos = True              neg : gen    =      5.2 : 1.0
#                     stop = True              neg : gen    =      5.2 : 1.0
#        californiaprimary = True              neg : pos    =      5.2 : 1.0
#                  they're = True              neg : pos    =      5.2 : 1.0
#                      app = True              neg : pos    =      5.2 : 1.0
#                     poll = True              pos : neg    =      5.1 : 1.0
#                     sign = True              pos : gen    =      5.0 : 1.0
#                 election = True              gen : neg    =      5.0 : 1.0
#                   starts = True              gen : pos    =      5.0 : 1.0
# None

# %%
test_tweet1 = "fsadfkadsfkhasdkhfkhsadfhkdsakhfkds"
custom_tweet_set = bag_of_words(test_tweet1)
prob_result = classifier.prob_classify(custom_tweet_set)
print ('Overall Result: ' + str(prob_result.max())) 
print ('Negative Tweet: ' + str(prob_result.prob("neg"))) 
print ('Positive Tweet: ' + str(prob_result.prob("pos")))
print ('General Tweet: ' + str(prob_result.prob("gen")))
tokens = get_tokens(test_tweet1)
# Out:
# Overall Result: gen
# Negative Tweet: 0.29269574356279554
# Positive Tweet: 0.35260115606936415
# General Tweet: 0.35470310036784025

# %%
df1['associated_candidate'] = found_match

# %%
test_tweet2 = "Amy Klobuchar"
custom_tweet_set = bag_of_words(test_tweet2)
prob_result = classifier.prob_classify(custom_tweet_set)
print ('Overall Result: ' + str(prob_result.max())) 
print ('Negative Tweet: ' + str(prob_result.prob("neg"))) 
print ('Positive Tweet: ' + str(prob_result.prob("pos")))
print ('General Tweet: ' + str(prob_result.prob("gen")))
# Out:
# Overall Result: pos
# Negative Tweet: 0.27209789851501076
# Positive Tweet: 0.7249842845130791
# General Tweet: 0.0029178169719105093

# %%
test_tweet3 = "Bernie sucks!"
custom_tweet_set = bag_of_words(test_tweet3)
prob_result = classifier.prob_classify(custom_tweet_set)
print ('Overall Result: ' + str(prob_result.max())) 
print ('Negative Tweet: ' + str(prob_result.prob("neg"))) 
print ('Positive Tweet: ' + str(prob_result.prob("pos")))
print ('General Tweet: ' + str(prob_result.prob("gen")))
# Out:
# Overall Result: neg
# Negative Tweet: 0.7462502013893247
# Positive Tweet: 0.2084031718372353
# General Tweet: 0.045346626773439175

# %%
candidates_full_name = ['Joe Biden', 'Amy Klobuchar', 'Pete Buttigieg', 'Bloomberg', 'Bernie Sanders', 'Elizabeth Warren']
candidates_last_name = ['Biden', 'Klobuchar', 'Buttigieg', 'Bloomberg', 'Sanders', 'Warren']

def get_sentiment(name):
    
    final_results = []
    
    for potential_pres in name:
        custom_tweet_set = bag_of_words(potential_pres)
        prob_result = classifier.prob_classify(custom_tweet_set)
        name = potential_pres
        results = str(prob_result.max()) 
        neg_results = str(prob_result.prob("neg"))
        pos_results = str(prob_result.prob("pos"))
        gen_results = str(prob_result.prob("gen"))
        create_dict = {'Name': name, 'Results': results, 'Negative Probability': neg_results, 'Positive Probability': pos_results,
                      'General Probability': gen_results}
        final_results.append(create_dict)
    
    return final_results

# %%
pre_sentiment = get_sentiment(candidates_last_name)

# %%
pre_sentiment
# Out:
# [{'Name': 'Biden',
#   'Results': 'neg',
#   'Negative Probability': '0.5199238815643935',
#   'Positive Probability': '0.4560721114220566',
#   'General Probability': '0.02400400701354983'},
#  {'Name': 'Klobuchar',
#   'Results': 'pos',
#   'Negative Probability': '0.35476889886497753',
#   'Positive Probability': '0.6129692758072477',
#   'General Probability': '0.03226182532777457'},
#  {'Name': 'Buttigieg',
#   'Results': 'pos',
#   'Negative Probability': '0.40418160387873053',
#   'Positive Probability': '0.4894214832560152',
#   'General Probability': '0.10639691286525435'},
#  {'Name': 'Bloomberg',
#   'Results': 'pos',
#   'Negative Probability': '0.4587476789474414',
#   'Positive Probability': '0.4824200846139234',
#   'General Probability': '0.05883223643863472'},
#  {'Name': 'Sanders',
#   'Results': 'pos',
#   'Negative Probability': '0.14620690433217434',
#   'Positive Probability': '0.7470681352142821',
#   'General Probability': '0.10672496045354342'},
#  {'Name': 'Warren',
#   'Results': 'pos',
#   'Negative Probability': '0.30226116868615727',
#   'Positive Probability': '0.6279643944170857',
#   'General Probability': '0.06977443689675639'}]

# %%
pre_df = pd.DataFrame(pre_sentiment)

# %%
pre_df.to_csv('pre_debate_candidate_sentiment.csv')

# %%
## Create the full file with all the predictions on it 

full_file = df1['text']

predictor = []

for i in full_file:
    full_tweets = bag_of_words(i)
    prob_result = classifier.prob_classify(full_tweets)
    predictor.append(str(prob_result.max()))
    
df1['predictor'] = predictor

positives = df1[df1['predictor']=='pos']
negatives = df1[df1['predictor']=='neg']
general = df1[df1['predictor']=='gen']

# %%
print("The amount of predicted general tweets were: {} \nThe amount of predicted positive tweets were: {} \nThe amount of predicted negative tweets were: {}".format(len(general),len(positives),len(negatives)))
# Out:
# The amount of predicted general tweets were: 2437
# The amount of predicted positive tweets were: 5217
# The amount of predicted negative tweets were: 6645

# %%
candidate_names = ['biden', 'klobuchar', 'buttigieg', 'bloomberg', 'sanders', 'warren',
                  'joe biden', 'amy klobuchar', 'pete buttigieg', 'michael bloomberg',
                   'bernie sanders', 'elizabeth warren',
                  'joe','amy','pete','michael','bernie','liz','elizabeth','bernard']
list_comp = []
found_match = []

for i,v in df1.iterrows():
    text = v['text']
    tokenize = get_tokens(text)
    list_comp = [name for name in tokenize if name in candidate_names]
    found_match.append(list_comp)

# %%
df1['associated_candidate'] = found_match

# %%
df1
# Out:
#       general pos_sentiment  pos_cand1  pos_cand2 pos_cand3 pos_cand4  \
# 0          no           yes    Sanders        NaN       NaN       NaN
# 1         yes            no        NaN        NaN       NaN       NaN
# 2          no           yes    Sanders        NaN       NaN       NaN
# 3          no           yes    Sanders        NaN       NaN       NaN
# 4         yes           NaN        NaN        NaN       NaN       NaN
# 5          no            no        NaN        NaN       NaN       NaN
# 6          no            no        NaN        NaN       NaN       NaN
# 7          no           yes  Buttigieg        NaN       NaN       NaN
# 8          no           yes    Sanders        NaN       NaN       NaN
# 9          no           yes    Sanders        NaN       NaN       NaN
# 10         no           yes     Warren        NaN       NaN       NaN
# 11         no           yes  Buttigieg        NaN       NaN       NaN
# 12         no           yes     Harris  Buttigieg       NaN       NaN
# 13        yes            no        NaN        NaN       NaN       NaN
# 14         no            no        NaN        NaN       NaN       NaN
# 15        yes            no        NaN        NaN       NaN       NaN
# 16        yes            no        NaN        NaN       NaN       NaN
# 17         no           yes    Sanders        NaN       NaN       NaN
# 18         no            no        NaN        NaN       NaN       NaN
# 19         no           yes      Biden        NaN       NaN       NaN
# 20         no            no        NaN        NaN       NaN       NaN
# 21        yes            no        NaN        NaN       NaN       NaN
# 22         no           yes     Caucus        NaN       NaN       NaN
# 23        yes            no        NaN        NaN       NaN       NaN
# 24        yes            no        NaN        NaN       NaN       NaN
# 25         no           yes     Caucus        NaN       NaN       NaN
# 26        yes            no        NaN        NaN       NaN       NaN
# 27        yes            no        NaN        NaN       NaN       NaN
# 28         no           yes      Biden        NaN       NaN       NaN
# 29         no            no        NaN        NaN       NaN       NaN
# ...       ...           ...        ...        ...       ...       ...
# 14269     NaN           NaN        NaN        NaN       NaN       NaN
# 14270     NaN           NaN        NaN        NaN       NaN       NaN
# 14271     NaN           NaN        NaN        NaN       NaN       NaN
# 14272     NaN           NaN        NaN        NaN       NaN       NaN
# 14273     NaN           NaN        NaN        NaN       NaN       NaN
# 14274     NaN           NaN        NaN        NaN       NaN       NaN
# 14275     NaN           NaN        NaN        NaN       NaN       NaN
# 14276     NaN           NaN        NaN        NaN       NaN       NaN
# 14277     NaN           NaN        NaN        NaN       NaN       NaN
# 14278     NaN           NaN        NaN        NaN       NaN       NaN
# 14279     NaN           NaN        NaN        NaN       NaN       NaN
# 14280     NaN           NaN        NaN        NaN       NaN       NaN
# 14281     NaN           NaN        NaN        NaN       NaN       NaN
# 14282     NaN           NaN        NaN        NaN       NaN       NaN
# 14283     NaN           NaN        NaN        NaN       NaN       NaN
# 14284     NaN           NaN        NaN        NaN       NaN       NaN
# 14285     NaN           NaN        NaN        NaN       NaN       NaN
# 14286     NaN           NaN        NaN        NaN       NaN       NaN
# 14287     NaN           NaN        NaN        NaN       NaN       NaN
# 14288     NaN           NaN        NaN        NaN       NaN       NaN
# 14289     NaN           NaN        NaN        NaN       NaN       NaN
# 14290     NaN           NaN        NaN        NaN       NaN       NaN
# 14291     NaN           NaN        NaN        NaN       NaN       NaN
# 14292     NaN           NaN        NaN        NaN       NaN       NaN
# 14293     NaN           NaN        NaN        NaN       NaN       NaN
# 14294     NaN           NaN        NaN        NaN       NaN       NaN
# 14295     NaN           NaN        NaN        NaN       NaN       NaN
# 14296     NaN           NaN        NaN        NaN       NaN       NaN
# 14297     NaN           NaN        NaN        NaN       NaN       NaN
# 14298     NaN           NaN        NaN        NaN       NaN       NaN
#
#       neg_sentiment  neg_cand1  neg_cand2 neg_cand3  ... favorites  \
# 0                no        NaN        NaN       NaN  ...         0
# 1                no        NaN        NaN       NaN  ...         0
# 2                no        NaN        NaN       NaN  ...        15
# 3                no        NaN        NaN       NaN  ...         0
# 4               NaN        NaN        NaN       NaN  ...         0
# 5               yes  Buttigieg      Trump       NaN  ...         0
# 6               yes  Buttigieg        NaN       NaN  ...         2
# 7                no        NaN        NaN       NaN  ...         0
# 8                no        NaN        NaN       NaN  ...         1
# 9               yes  Bloomberg        NaN       NaN  ...         0
# 10              yes  Bloomberg        NaN       NaN  ...         0
# 11               no        NaN        NaN       NaN  ...         1
# 12              yes  Bloomberg    Sanders       NaN  ...         0
# 13               no        NaN        NaN       NaN  ...         1
# 14              yes    Sanders        NaN       NaN  ...         0
# 15               no        NaN        NaN       NaN  ...         0
# 16               no        NaN        NaN       NaN  ...         0
# 17               no        NaN        NaN       NaN  ...         0
# 18              yes     Caucus        DNC       NaN  ...         0
# 19               no        NaN        NaN       NaN  ...         1
# 20              yes  Buttigieg  Bloomberg       NaN  ...         0
# 21               no        NaN        NaN       NaN  ...         0
# 22               no        NaN        NaN       NaN  ...         3
# 23               no        NaN        NaN       NaN  ...         0
# 24               no        NaN        NaN       NaN  ...         1
# 25              yes     Caucus        NaN       NaN  ...         0
# 26               no        NaN        NaN       NaN  ...         0
# 27               no        NaN        NaN       NaN  ...        17
# 28              yes    Sanders        NaN       NaN  ...         3
# 29              yes     Caucus        NaN       NaN  ...         0
# ...             ...        ...        ...       ...  ...       ...
# 14269           NaN        NaN        NaN       NaN  ...         0
# 14270           NaN        NaN        NaN       NaN  ...         0
# 14271           NaN        NaN        NaN       NaN  ...         1
# 14272           NaN        NaN        NaN       NaN  ...         0
# 14273           NaN        NaN        NaN       NaN  ...        37
# 14274           NaN        NaN        NaN       NaN  ...         0
# 14275           NaN        NaN        NaN       NaN  ...         0
# 14276           NaN        NaN        NaN       NaN  ...         0
# 14277           NaN        NaN        NaN       NaN  ...         2
# 14278           NaN        NaN        NaN       NaN  ...         1
# 14279           NaN        NaN        NaN       NaN  ...         2
# 14280           NaN        NaN        NaN       NaN  ...         0
# 14281           NaN        NaN        NaN       NaN  ...         0
# 14282           NaN        NaN        NaN       NaN  ...         7
# 14283           NaN        NaN        NaN       NaN  ...         0
# 14284           NaN        NaN        NaN       NaN  ...         4
# 14285           NaN        NaN        NaN       NaN  ...         1
# 14286           NaN        NaN        NaN       NaN  ...         0
# 14287           NaN        NaN        NaN       NaN  ...         0
# 14288           NaN        NaN        NaN       NaN  ...         1
# 14289           NaN        NaN        NaN       NaN  ...         0
# 14290           NaN        NaN        NaN       NaN  ...         7
# 14291           NaN        NaN        NaN       NaN  ...         1
# 14292           NaN        NaN        NaN       NaN  ...         2
# 14293           NaN        NaN        NaN       NaN  ...         3
# 14294           NaN        NaN        NaN       NaN  ...         2
# 14295           NaN        NaN        NaN       NaN  ...         9
# 14296           NaN        NaN        NaN       NaN  ...        40
# 14297           NaN        NaN        NaN       NaN  ...         0
# 14298           NaN        NaN        NaN       NaN  ...         5
#
#               username                                               text  \
# 0        DeannaLee1369  Bernie Sanders Gains Endorsement From Latinx G...
# 1             8NewsNow  Today is the final day of early voting ahead o...
# 2         BilldeBlasio  The #NevadaCaucus is absolutely crucial to @Be...
# 3             SalKappa  #PresidentSanders #BernieWonIowa #BernieWonNew...
# 4        chad_b_morrow  Absolutely absurd how long the line is for ear...
# 5          DestiGrace1  Lordie the discussion is about dirty AF #Corru...
# 6       iamwillkeating  #MayorPete Buttigieg just said his religious f...
# 7        Magsaliciouss  Just picked up my Precinct Captain box for Sat...
# 8         GoHawksThe12  Bernie is now the ONLY candidate with NO billi...
# 9      pearshavehearti  #BernieSanders2020 #NotMeUs #Bernie2020 #Berni...
# 10                JSto  Y'all he's also a debate no show unless he can...
# 11          dannarossi  Only a little bit into @PeteButtigieg #PeteOnC...
# 12             pemdave  No dog in this fight since #KamalaHarris got p...
# 13             SMikeMD  Waiting in line to vote early for the Nevada c...
# 14       Anti_Leftist_  Our country is $23T in debt. Bernie has over $...
# 15          1nd1obravo            Alcalde Pedro sounds good #NevadaCaucus
# 16     growing0up0girl  I can only hope he has a shitload better groun...
# 17       ZachMoonshine  Kim Gordon canvassing for Bernie Sanders - @th...
# 18          etrnlvista  Sounds like #NevadaCaucus could be a repeat of...
# 19     AngelNoMalarkey  Damn...that was quite powerful #Biden2020 #Nev...
# 20        Zeuswantsyou  @CNN of course @PeteButtigieg is going to take...
# 21       BentheosBrown  Nevada caucus: Who can show strength with vote...
# 22            notake94  As the first early voting period with a Caucus...
# 23        bernie_ebook  Thanks for visiting our Nevada team & caucus-g...
# 24     OfficialBrohoss                                 solidarity forever
# 25     RealRyanWorkman  Nevada early voters give revamped caucus proce...
# 26     billymjonesMACK  Nevada attempts to avoid repeat of Iowa caucus...
# 27               MSNBC  Wednesday at 9 p.m. ET: @MSNBC and @NBCNews ho...
# 28         Deemoney521  I might be NUTS but it seems like #grifterbern...
# 29      MelissaPederse  Will Nevada become another Iowa caucus debacle...
# ...                ...                                                ...
# 14269          sanz_md  If Bernie is seriously trying to win then he m...
# 14270   carmenVhulbert  Highly suspicious! The main players are strate...
# 14271      Willowinski               Not Nevada Caucus but Nevada Circus!
# 14272  LatinosProgres1  #MayorCheat is at it again, now he is trying t...
# 14273       grantstern  As well they should. Iowa's small population a...
# 14274           Xuubat  Oh yeah, Pete's campaign organizer is literall...
# 14275    ExaltedUterus  #NevadaCaucus #Election2020 #Primary2020https:...
# 14276   MimiTexasAngel  #NevadaCaucus invites same folks in from #IDP ...
# 14277      Evolvingtoo  #DNCRigged #dncwakeup #NevadaCaucus #DNCFraudL...
# 14278      RuinDweller  #NevadaCaucus #NVCaucushttps://twitter.com/dan...
# 14279  ethicalpsycholo  Nevada Democratic Party advertised that no one...
# 14280        thekohler  You said Nevada is 52% PoC. What percentage of...
# 14281       Tim_Tunden  After the Iowa debacle #NevadaCaucus Dems were...
# 14282    lauralynnRay2  What about former executive director of Nevada...
# 14283      clevergrrly  And to set the record straight... 41% of Nevad...
# 14284  SELENAH43482974  #tomsteyer #kids #tom2020 #allamericanfamily #...
# 14285       VotingRed1  @realDonaldTrump Why aren't we serious about v...
# 14286   solongsweeties  He - @PeteButtigieg - is an opportunistic copy...
# 14287     palbirdiebro  NEW: Nevada Democrats are developing a new "to...
# 14288       elcostello  Buttigieg Iowa Organizer hired to be Nevada Ca...
# 14289    geography_pro  The fix is in for Nevada. Another Mayor Pete c...
# 14290  nashville_brook  First Nevada claimed it wouldn’t be using the ...
# 14291       NewDawgFlo  It’s like they’re mad for nothing. MSM Establi...
# 14292       fh_saoirse  mt . @shaunking . @Greg_Palast . @Thom_Hartman...
# 14293        AmyRangel  I hope everyone films and documents everything...
# 14294      niggaopolis  Now Pete gets days of a victory lap. Boosting ...
# 14295      DeanBaker13  And, they were able to get results the same da...
# 14296    fernandez2126  You know, Tulsi should probably skip Nevada an...
# 14297       Sonicsnout  Voter Protection Director for the upcoming Nev...
# 14298  natalywithcurls  Y'all did @RogerLau came to Nevada to talk to ...
#
#        geo                                           mentions  \
# 0      NaN                                                NaN
# 1      NaN                                                NaN
# 2      NaN                                     @BernieSanders
# 3      NaN                                                NaN
# 4      NaN                                                NaN
# 5      NaN                                            @maddow
# 6      NaN                                                NaN
# 7      NaN                                     @PeteButtigieg
# 8      NaN                                                NaN
# 9      NaN                                                NaN
# 10     NaN                                                NaN
# 11     NaN                                     @PeteButtigieg
# 12     NaN                                                NaN
# 13     NaN                                                NaN
# 14     NaN                                                NaN
# 15     NaN                                                NaN
# 16     NaN                                                NaN
# 17     NaN                                          @thebeast
# 18     NaN                                                NaN
# 19     NaN                                                NaN
# 20     NaN                 @CNN @PeteButtigieg @MikeBloomberg
# 21     NaN                                                NaN
# 22     NaN        @SarahMahler1 @ljsinclair @bluelyon @nvdems
# 23     NaN                                                NaN
# 24     NaN                                                NaN
# 25     NaN                                                NaN
# 26     NaN                                                NaN
# 27     NaN                                    @MSNBC @NBCNews
# 28     NaN                                                NaN
# 29     NaN                                                NaN
# ...    ...                                                ...
# 14269  NaN                                                NaN
# 14270  NaN                                     @BernieSanders
# 14271  NaN                                                NaN
# 14272  NaN                                                NaN
# 14273  NaN                                                NaN
# 14274  NaN                                                NaN
# 14275  NaN                                                NaN
# 14276  NaN                                                NaN
# 14277  NaN                                                NaN
# 14278  NaN                                                NaN
# 14279  NaN                                                NaN
# 14280  NaN                                                NaN
# 14281  NaN                                                NaN
# 14282  NaN                                                NaN
# 14283  NaN                                                NaN
# 14284  NaN                                                NaN
# 14285  NaN                                   @realDonaldTrump
# 14286  NaN                                     @PeteButtigieg
# 14287  NaN                                                NaN
# 14288  NaN                                                NaN
# 14289  NaN                                                NaN
# 14290  NaN                                                NaN
# 14291  NaN                                               @DNC
# 14292  NaN  @shaunking @Greg_Palast @Thom_Hartmann @jeffer...
# 14293  NaN                                                NaN
# 14294  NaN                                                NaN
# 14295  NaN                                                NaN
# 14296  NaN                                                NaN
# 14297  NaN                                                NaN
# 14298  NaN                                          @RogerLau
#
#                                                 hashtags            id  \
# 0                                                    NaN  1.229957e+18
# 1                                              #8NNhttps  1.229956e+18
# 2                                    #NevadaCaucus #UNLV  1.229956e+18
# 3      #PresidentSanders #BernieWonIowa #BernieWonNew...  1.229956e+18
# 4                                          #NevadaCaucus  1.229956e+18
# 5      #CorruptBarr #Maddow #PeteButtigieg #DisBarr #...  1.229956e+18
# 6      #MayorPete #NevadaCaucus #2020election #CNNTow...  1.229955e+18
# 7                                              #TeamPete  1.229955e+18
# 8      #warren2020 #Bernie2020 #PetesBillionaires #Wa...  1.229955e+18
# 9      #BernieSanders2020 #NotMeUs #Bernie2020 #Berni...  1.229955e+18
# 10                  #Democrats #Warren2020 #NevadaCaucus  1.229955e+18
# 11     #PeteOnCNN #TeamPete #NevadaCaucus #NevadaForPete  1.229955e+18
# 12     #KamalaHarris #MayoPete #NeverBloomberg #Nevad...  1.229955e+18
# 13                                                   NaN  1.229955e+18
# 14     #socialism #Bernie2020 #NevadaCaucus #Election...  1.229954e+18
# 15                                         #NevadaCaucus  1.229954e+18
# 16                                                   NaN  1.229954e+18
# 17                                                   NaN  1.229954e+18
# 18     #NevadaCaucus #Iowa #BernieSanders #NevadaCauc...  1.229954e+18
# 19                              #Biden2020 #NevadaCaucus  1.229954e+18
# 20                              #NevadaCaucus #winecaves  1.229954e+18
# 21                                                   NaN  1.229954e+18
# 22                                                 #Doug  1.229954e+18
# 23                                                   NaN  1.229953e+18
# 24                                                   NaN  1.229953e+18
# 25                                              #FoxNews  1.229953e+18
# 26                                                   NaN  1.229953e+18
# 27                                            #DemDebate  1.229953e+18
# 28     #grifterbernie #gaslight #democrats #Iowa #new...  1.229953e+18
# 29                              #potus2020 #demdebatepic  1.229953e+18
# ...                                                  ...           ...
# 14269                                                NaN  1.226657e+18
# 14270                                           #NotMeUs  1.226656e+18
# 14271                                                NaN  1.226656e+18
# 14272  #MayorCheat #MayoCheat #WineCavePete #MayorPet...  1.226656e+18
# 14273                                                NaN  1.226656e+18
# 14274                                             #Unity  1.226656e+18
# 14275      #NevadaCaucus #Election2020 #Primary2020https  1.226655e+18
# 14276  #NevadaCaucus #IDP #SCANDAL #Democrats #CORRUP...  1.226655e+18
# 14277  #DNCRigged #dncwakeup #NevadaCaucus #DNCFraudL...  1.226655e+18
# 14278                       #NevadaCaucus #NVCaucushttps  1.226655e+18
# 14279                                                NaN  1.226654e+18
# 14280                                                NaN  1.226654e+18
# 14281                                      #NevadaCaucus  1.226654e+18
# 14282                                                NaN  1.226653e+18
# 14283                                                NaN  1.226653e+18
# 14284  #tomsteyer #kids #tom2020 #allamericanfamily #...  1.226653e+18
# 14285                                      #NevadaCaucus  1.226653e+18
# 14286                            #NevadaCaucus #DNChttps  1.226652e+18
# 14287           #IowaCaucusDisaster #TomPerezResignhttps  1.226652e+18
# 14288                                                NaN  1.226651e+18
# 14289                                                NaN  1.226651e+18
# 14290                                                NaN  1.226651e+18
# 14291                  #IowaCaucusDisaster #NevadaCaucus  1.226651e+18
# 14292  #VoterSuppression #Election2020 #NEVADACaucus ...  1.226651e+18
# 14293                                                NaN  1.226651e+18
# 14294                                                NaN  1.226651e+18
# 14295                                                NaN  1.226651e+18
# 14296                                                NaN  1.226651e+18
# 14297                                                NaN  1.226651e+18
# 14298                                                NaN  1.226650e+18
#
#                                                permalink  \
# 0      https://twitter.com/DeannaLee1369/status/12299...
# 1      https://twitter.com/8NewsNow/status/1229956270...
# 2      https://twitter.com/BilldeBlasio/status/122995...
# 3      https://twitter.com/SalKappa/status/1229956122...
# 4      https://twitter.com/chad_b_morrow/status/12299...
# 5      https://twitter.com/DestiGrace1/status/1229955...
# 6      https://twitter.com/iamwillkeating/status/1229...
# 7      https://twitter.com/Magsaliciouss/status/12299...
# 8      https://twitter.com/GoHawksThe12/status/122995...
# 9      https://twitter.com/pearshavehearti/status/122...
# 10     https://twitter.com/JSto/status/12299546627255...
# 11     https://twitter.com/dannarossi/status/12299545...
# 12     https://twitter.com/pemdave/status/12299545768...
# 13     https://twitter.com/SMikeMD/status/12299545239...
# 14     https://twitter.com/Anti_Leftist_/status/12299...
# 15     https://twitter.com/1nd1obravo/status/12299542...
# 16     https://twitter.com/growing0up0girl/status/122...
# 17     https://twitter.com/ZachMoonshine/status/12299...
# 18     https://twitter.com/etrnlvista/status/12299539...
# 19     https://twitter.com/AngelNoMalarkey/status/122...
# 20     https://twitter.com/Zeuswantsyou/status/122995...
# 21     https://twitter.com/BentheosBrown/status/12299...
# 22     https://twitter.com/notake94/status/1229953511...
# 23     https://twitter.com/bernie_ebook/status/122995...
# 24     https://twitter.com/OfficialBrohoss/status/122...
# 25     https://twitter.com/RealRyanWorkman/status/122...
# 26     https://twitter.com/billymjonesMACK/status/122...
# 27     https://twitter.com/MSNBC/status/1229952744028...
# 28     https://twitter.com/Deemoney521/status/1229952...
# 29     https://twitter.com/MelissaPederse/status/1229...
# ...                                                  ...
# 14269  https://twitter.com/sanz_md/status/12266565873...
# 14270  https://twitter.com/carmenVhulbert/status/1226...
# 14271  https://twitter.com/Willowinski/status/1226656...
# 14272  https://twitter.com/LatinosProgres1/status/122...
# 14273  https://twitter.com/grantstern/status/12266557...
# 14274  https://twitter.com/Xuubat/status/122665561115...
# 14275  https://twitter.com/ExaltedUterus/status/12266...
# 14276  https://twitter.com/MimiTexasAngel/status/1226...
# 14277  https://twitter.com/Evolvingtoo/status/1226655...
# 14278  https://twitter.com/RuinDweller/status/1226654...
# 14279  https://twitter.com/ethicalpsycholo/status/122...
# 14280  https://twitter.com/thekohler/status/122665395...
# 14281  https://twitter.com/Tim_Tunden/status/12266539...
# 14282  https://twitter.com/lauralynnRay2/status/12266...
# 14283  https://twitter.com/clevergrrly/status/1226653...
# 14284  https://twitter.com/SELENAH43482974/status/122...
# 14285  https://twitter.com/VotingRed1/status/12266530...
# 14286  https://twitter.com/solongsweeties/status/1226...
# 14287  https://twitter.com/palbirdiebro/status/122665...
# 14288  https://twitter.com/elcostello/status/12266511...
# 14289  https://twitter.com/geography_pro/status/12266...
# 14290  https://twitter.com/nashville_brook/status/122...
# 14291  https://twitter.com/NewDawgFlo/status/12266509...
# 14292  https://twitter.com/fh_saoirse/status/12266509...
# 14293  https://twitter.com/AmyRangel/status/122665095...
# 14294  https://twitter.com/niggaopolis/status/1226650...
# 14295  https://twitter.com/DeanBaker13/status/1226650...
# 14296  https://twitter.com/fernandez2126/status/12266...
# 14297  https://twitter.com/Sonicsnout/status/12266505...
# 14298  https://twitter.com/natalywithcurls/status/122...
#
#                          associated_candidate predictor
# 0                           [bernie, sanders]       pos
# 1                                          []       gen
# 2                                          []       pos
# 3                           [bernie, sanders]       pos
# 4                                          []       neg
# 5                                          []       neg
# 6                                 [buttigieg]       neg
# 7                                          []       pos
# 8      [bernie, warren, bernie, biden, biden]       pos
# 9                                    [bernie]       pos
# 10                                   [warren]       pos
# 11                                         []       pos
# 12                                   [bernie]       neg
# 13                                         []       gen
# 14                           [bernie, bernie]       neg
# 15                                         []       neg
# 16                                         []       gen
# 17                          [bernie, sanders]       gen
# 18                                         []       neg
# 19                                    [biden]       pos
# 20                                     [pete]       neg
# 21                                         []       pos
# 22                                         []       pos
# 23                                         []       pos
# 24                                         []       gen
# 25                                         []       neg
# 26                                         []       neg
# 27                                         []       gen
# 28                                   [bernie]       neg
# 29                                         []       gen
# ...                                       ...       ...
# 14269               [bernie, buttigieg, pete]       neg
# 14270                                      []       neg
# 14271                                      []       gen
# 14272                                      []       neg
# 14273                                      []       pos
# 14274                                  [pete]       neg
# 14275                                      []       gen
# 14276                                      []       neg
# 14277                                      []       pos
# 14278                                      []       pos
# 14279                                      []       neg
# 14280                                      []       neg
# 14281                                      []       neg
# 14282                                  [pete]       neg
# 14283                                      []       pos
# 14284                                      []       neg
# 14285                                      []       neg
# 14286                                      []       neg
# 14287                                      []       neg
# 14288                             [buttigieg]       neg
# 14289                                  [pete]       neg
# 14290                                      []       neg
# 14291                             [bloomberg]       pos
# 14292                                      []       neg
# 14293                                      []       pos
# 14294                                  [pete]       neg
# 14295                                      []       neg
# 14296                                      []       neg
# 14297                                  [pete]       neg
# 14298                                      []       neg
#
# [14299 rows x 25 columns]

# %%
import pickle
filename = 'pre_debate_model.sav'
pickle.dump(classifier, open(filename, 'wb'))

# %%
df1.to_csv('pre_debate_predicted_new_with_candidate.csv')

# %%
df1

# %%
## Predict results of the post debate tweet set

df2 = pd.read_csv('nevada_caucus_2_19_post_debate.csv', encoding='utf8')

post_debate = df2['text']

post_debate_predictor = []

for i in post_debate:
    full_tweets = bag_of_words(i)
    prob_result = classifier.prob_classify(full_tweets)
    post_debate_predictor.append(str(prob_result.max()))
    
df2['predictor'] = post_debate_predictor

df2.to_csv('post_debate_file.csv')

# %%
## Predict results of the pre-election set 

df3 = pd.read_csv('nevada_caucus_pre_election_2_21.csv', encoding='utf8')

pre_election = df3['text']

pre_election_pred = []

for i in pre_election:
    full_tweets = bag_of_words(i)
    prob_result = classifier.prob_classify(full_tweets)
    pre_election_pred.append(str(prob_result.max()))
    
df3['predictor'] = pre_election_pred

df3.to_csv('pre_election_file.csv')

# %%
## Predict results of the post-election set

df4 = pd.read_csv('nevada_caucus_post_election_2_24.csv', encoding='utf8')

post_elec = df4['text']

post_elec_pred = []

for i in post_elec:
    full_tweets = bag_of_words(i)
    prob_result = classifier.prob_classify(full_tweets)
    post_elec_pred.append(str(prob_result.max()))
    
df4['predictor'] = post_elec_pred

df4.to_csv('post_election_file.csv')

# %%
pre_elect_df = pd.read_csv('pre_election_file.csv')

# %%
post_elect_df = pd.read_csv('post_election_file.csv')

# %%
post_elect_df.head()
# Out:
#    Unnamed: 0                date       username               to  replies  \
# 0           0  2020-02-25 1:23:21     Stanlee011              NaN        0
# 1           1  2020-02-25 1:22:52    KayanaMaree              NaN        0
# 2           2  2020-02-25 1:22:49       scldef22              NaN        0
# 3           3  2020-02-25 1:22:12  BlackAmCaucus              NaN        0
# 4           4  2020-02-25 1:21:25  uniquechoices  kristenluvslife        0
#
#    retweets  favorites                                               text  \
# 0         0          0  Nevada Caucus Final Results: Bernie 47%, Biden...
# 1         0          0  The ladies at @TheView just don't get it!!! Th...
# 2         0          0           @RedEaglePatriot Nevada caucus analysis?
# 3         1          2  Nevada Democratic Caucus Turnout: 2020 - 105,1...
# 4         0          0  Not just that won around 27K out of 3M in #Nev...
#
#    geo           mentions       hashtags            id  \
# 0  NaN    @thelastrefuge2            NaN  1.232114e+18
# 1  NaN  @TheView @YouTube            NaN  1.232114e+18
# 2  NaN   @RedEaglePatriot            NaN  1.232114e+18
# 3  NaN                NaN  #NevadaCaucus  1.232114e+18
# 4  NaN                NaN  #NevadaCaucus  1.232113e+18
#
#                                            permalink predictor
# 0  https://twitter.com/Stanlee011/status/12321138...       pos
# 1  https://twitter.com/KayanaMaree/status/1232113...       pos
# 2  https://twitter.com/scldef22/status/1232113689...       gen
# 3  https://twitter.com/BlackAmCaucus/status/12321...       gen
# 4  https://twitter.com/uniquechoices/status/12321...       pos

# %%
def create_array(dataframe):
    candidate_names = ['biden', 'klobuchar', 'buttigieg', 'bloomberg', 'sanders', 'warren',
                      'joe biden', 'amy klobuchar', 'pete buttigieg', 'michael bloomberg',
                       'bernie sanders', 'elizabeth warren',
                      'joe','amy','pete','michael','bernie','liz','elizabeth','bernard']
    list_comp = []
    found_match = []

    for i,v in dataframe.iterrows():
        text = v['text']
        tokenize = get_tokens(text)
        list_comp = [name for name in tokenize if name in candidate_names]
        found_match.append(list_comp)
        
    dataframe['associated_candidate'] = found_match
    return dataframe

# %%
final_pre_elect_df = create_array(pre_elect_df)

# %%
final_post_elect_df = create_array(post_elect_df)

# %%
final_pre_elect_df.to_csv('pre_election_predicted.csv')

# %%
final_post_elect_df.to_csv('post_election_predicted.csv')
